# %% [markdown]
# <a href="https://colab.research.google.com/github/cycling777/azureSpeech/blob/main/AzureSpeech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-cognitiveservices-speech
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import azure.cognitiveservices.speech as speechsdk
from IPython.display import Audio, display

# Set parameters of your subscription
subscription = "your subscription key" #@param {type:"string"}
region = "your region" #@param {type:"string"}

# This example requires environment variables named "SPEECH_KEY" and "SPEECH_REGION"
speech_config = speechsdk.SpeechConfig(subscription=subscription, region=region)
audio_file_path = "test.wav"
audio_config = speechsdk.audio.AudioOutputConfig(filename=audio_file_path)

# The language of the voice that speaks.
speech_config.speech_synthesis_language = "ja-JP" 
speech_config.speech_synthesis_voice_name ='ja-JP-NanamiNeural' #@param ["ja-JP-AoiNeural", "ja-JP-DaichiNeural", "ja-JP-KeitaNeural", "ja-JP-MayuNeural", "ja-JP-NanamiNeural", "ja-JP-NaokiNeural", "ja-JP-ShioriNeural"] {allow-input: false}

speech_synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=audio_config)

# Get text from the console and synthesize to the default speaker.
text = "\u3053\u3053\u306E\u6587\u7AE0\u3092\u5909\u66F4\u3057\u3066\u304A\u8A66\u3057\u304F\u3060\u3055\u3044\u3002"#@param {type:"string"}

speech_synthesis_result = speech_synthesizer.speak_text_async(text).get()

if speech_synthesis_result.reason == speechsdk.ResultReason.SynthesizingAudioCompleted:
    print("Speech synthesized for text [{}]".format(text))
elif speech_synthesis_result.reason == speechsdk.ResultReason.Canceled:
    cancellation_details = speech_synthesis_result.cancellation_details
    print("Speech synthesis canceled: {}".format(cancellation_details.reason))
    if cancellation_details.reason == speechsdk.CancellationReason.Error:
        if cancellation_details.error_details:
            print("Error details: {}".format(cancellation_details.error_details))
            print("Did you set the speech resource key and region values?")

display(Audio(audio_file_path, autoplay=True))
# Out:
# Speech synthesized for text [ここの文章を変更してお試しください。]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
